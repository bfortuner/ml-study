# %%
import keras.backend as K

def limit_mem():
    K.get_session().close() #new line lets you reset GPU memory without closing notebook
    cfg = K.tf.ConfigProto()
    cfg.gpu_options.allow_growth = True
    K.set_session(K.tf.Session(config=cfg))
limit_mem()
# Out:
# Using TensorFlow backend.

# %%
DATA_PATH = '/home/bfortuner/workplace/data/jokes/'

# %%
jokes = pd.read_csv(DATA_PATH+'shortjokesclean.txt')

# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(DATA_PATH+'shortjokesclean.txt').read().lower()[:100000]
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 150
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=128, nb_epoch=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.8]: #0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
# Out:
# corpus length: 100000
# total chars: 63
# nb sequences: 33284
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
#  - ETA: 4s - loss: 2.6418
#
# ----- diversity: 0.8
# ----- Generating with seed: "e calls? he just monkeys around on the line!
# kids are like farts. you don't mind your own, but others peoples are just unbearable
# over the past year, "
# e calls? he just monkeys around on the line!
# kids are like farts. you don't mind your own, but others peoples are just unbearable
# over the past year, wold ver ste th the (a bat a psoon gust the conk the callt ut st" the "it thes the rifating on my at my tte the ning.
# whe to m to the the plops cheve te it wabl a lan tre ti the "ben the the  i sth stx
# m to thin lof do jur the sow to tho to back nei so don prone the soprad the pon stat the jund teced what't the thin in the the the ting th to the at the an thet co st nick t tty couse the  a dont go
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 33284/33284 [==============================] - 26s - loss: 2.1578
#
# ----- diversity: 0.8
# ----- Generating with seed: "ople's lunches from the break room & blaming the taliban. a lot of what you've been stealing is pork for one thing.
# my wife says she's leaving me beca"
# ople's lunches from the break room & blaming the taliban. a lot of what you've been stealing is pork for one thing.
# my wife says she's leaving me becab-asht.
# what iachal i hif hill lrall". of hen't amer aftar? on i wald'te learle of a poest,
# metoore of hit the bot feveracm a athar shem ho you bet talla9 oiched go a muacks if ped fare.
# dow theof amoreter laep.
# me beally weake in a thes bueb and om a crire is stooncred-"deow than you all fickicans of afled of experooliall* prud a ald with o a adiacring so bedyore beclichadese.
# what ded it wifn a
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 33284/33284 [==============================] - 26s - loss: 1.9873
#
# ----- diversity: 0.8
# ----- Generating with seed: "to wear and something to play with. so they got me a pair of pants with the pockets cut out.
# with 10k characters, i can finally get into great detail "
# to wear and something to play with. so they got me a pair of pants with the pockets cut out.
# with 10k characters, i can finally get into great detail a sos a crins. somen ouscad ant now
# when it of its and ginging
# mels no goontoof? get look tons toosmoroolecian "ben sop like to conal onk a sonkmoon? i till soing adoun ortat be and dibly now a seis.
# when a cand, to bight or man so bost reat peeving don.
# cocleng for to to seen i reat baygiar. boopmion.
# hid to me a outure bolave of manking topysiont to when is do gonghone.
# i to i fontere.
# do gight
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
#  - ETA: 22s - loss: 1.8388
#
# ----- diversity: 0.8
# ----- Generating with seed: "tion because a baby would ruin my holiday plans.
# when someone uses the bathroom and asks about the wine cork floating in the toilet is why i don't inv"
# tion because a baby would ruin my holiday plans.
# when someone uses the bathroom and asks about the wine cork floating in the toilet is why i don't inverpe "prout all pill a gurt.
# what you'm cashers rap.
# the bacause i have she doss borbaur? calk they to mugite to baghting shasen the rlef sure they siend what i's moge a choom of you what h: wheres becamsough halk in the mundlaw a k of where sial pitsen that the snally soe donally horse have shat, "he works the blly meen happhing... out.
# what did the top logita muss, nersting reatiesably gond wher
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 33284/33284 [==============================] - 26s - loss: 1.7413
#
# ----- diversity: 0.8
# ----- Generating with seed: "ange a light bulb in brazil? a brazillion!!! http://imgur.com/c4cjjud
# how do you make an amish woman happy? three men-a-night
# letsh have shex! -horny "
# ange a light bulb in brazil? a brazillion!!! http://imgur.com/c4cjjud
# how do you make an amish woman happy? three men-a-night
# letsh have shex! -horny think its my plantbe a noughanians
# whan did you gousinnless dinger senna idrence a crubmetopnan invoring" thutsers intering: the prondsing... ut!
# i have the pyosh i have hing of the make her thence of sacks the cunspuntin the and nevery med a letsenat twatts han trooses
# a knoman shill white the hantsas to dis: when my shates? haling knogh all at in the playsting in a the a d-cencess surnex
# i condi
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
#  - ETA: 3s - loss: 1.6316
#
# ----- diversity: 0.8
# ----- Generating with seed: "e' & remind me of myself. as a consumer this makes me feel good. now i will purchase all their products
# the first rule of procrastination club is: goo"
# e' & remind me of myself. as a consumer this makes me feel good. now i will purchase all their products
# the first rule of procrastination club is: goonlisp.
# snial what that ganging to thied hor twher ispat and say: his noingel himparing "seed. i was like deck of strathing like me.
# i don't lover you.
# than i sppprionally biggerwarks always feretim you like a stirlly bali? it basing dimbie you spand they what you weske me easting stairs? thoke bath strmes as a pan perders indersaly into mole in a disere of cyers ars whe diece that w
